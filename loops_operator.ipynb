# %% [markdown]
# # loop

# %%
i = 0
while i<=10:
    print(f"hello {i}")
    i +=1
# Out:
# hello 0
# hello 1
# hello 2
# hello 3
# hello 4
# hello 5
# hello 6
# hello 7
# hello 8
# hello 9
# hello 10

# %% [markdown]
# ### Questions of while loop

# %% [markdown]
# 1. print all the numbers which are divisible by 3 and 5, from 1 to 100

# %%
i=1
while i<=100:
    if i%3 == 0 and i%5 == 0:
        print(i, end=" ")
    i +=1
# Out:
# 15 30 45 60 75 90

# %% [markdown]
# 2. Sum of all the numbers from 1 to 100

# %%
total_sum = 0
i = 1
while i<=100:
    total_sum += i
    i +=1
print(f"Total sum: {total_sum}")
# Out:
# Total sum: 5050

# %% [markdown]
# 3. Sum of all numbers from 1 to 100 divisible by 2 and 7.

# %%
total_sum_of_2_7 = 0
i = 1
while i<=100:
    if i%2 ==0 and i%7 == 0:
        total_sum_of_2_7 +=i
    i+= 1
print(f"Total sum of divisible by 2 and 7: {total_sum_of_2_7}")
# Out:
# Total sum of divisible by 2 and 7: 392

# %% [markdown]
# ### Nested Loop

# %% [markdown]
# 1.  *
#     *   *
#     *   *   *
#     *   *   *   *
#     *   *   *   *   *

# %%
for i in range(1, 6):
    for j in range (1, i+1):
        print("*", end=" ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# question 2.
# 1
# 2   1
# 3   2   1
# 4   3   2   1
# 5   4   3   2   1

# %%
for i in range(1, 6):
    for j in range(i, 0, -1):
        print(j, end=" ")
    print()
# Out:
# 1
# 2 1
# 3 2 1
# 4 3 2 1
# 5 4 3 2 1

# %% [markdown]
# question 3.
# 1   2   3   4   5
# 1   2   3   4
# 1   2   3
# 1   2
# 1

# %%
for i in range(5,0,-1):
    for j in range(1, i+1):
        print(j, end=" ")
    print()
# Out:
# 1 2 3 4 5
# 1 2 3 4
# 1 2 3
# 1 2
# 1

# %%
for i in range(1,6):
    for j in range(5, i-1,-1):
        print(j, end=" ")
    print()
# Out:
# 5 4 3 2 1
# 5 4 3 2
# 5 4 3
# 5 4
# 5

# %% [markdown]
# question 5.
# 5   4   3   2   1
# 4   3   2   1
# 3   2   1
# 2   1
# 1

# %%
for i in range(5,0,-1):
    for j in range(i,0,-1):
        print(j,end=" ")
    print()
# Out:
# 5 4 3 2 1
# 4 3 2 1
# 3 2 1
# 2 1
# 1
